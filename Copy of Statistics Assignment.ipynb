# %%
import numpy as np
import pandas as pd
import seaborn as sns
import statistics as stat
from scipy import stats
import matplotlib.pyplot as plt
import math

# %%
#1  Generate a list of 100 integers containing values between 90 to 130 and store it in the variable `int_list`. After generating the list, find the following:

#(i) Write a Python function to calculate the mean of a given list of numbers. Create a function to find the median of a list of numbers.

int_list= np.random.randint(90,130,100)

mean_list=np.mean(int_list)
print("Mean of the list is",mean_list)
print("Median of the list is", np.median(int_list))

#ii) Develop a program to compute the mode of a list of integers

print("The mode of the integer list is:",stat.mode(int_list))

# (iii) Implement a function to calculate the weighted mean of a list of values and their corresponding weights.

#(iv) Write a Python function to find the geometric mean of a list of positive numbers.

print("The geometric mean of the list of integers is",stat.geometric_mean(int_list))

#(v) Create a program to calculate the harmonic mean of a list of values

print("The harmonic mean of the list of values is",stat.harmonic_mean(int_list))

#(vi) ) Build a function to determine the midrange of a list of numbers (average of the minimum and maximum)

print("The midrange of the given list is:",(max(int_list)+min(int_list))/2)

#) Implement a Python program to find the trimmed mean of a list, excluding a certain percentage of outliers

print("The trimmed mean for the given data is:",stats.trim_mean(int_list,0.1))
# Out:
# Mean of the list is 108.93
# Median of the list is 108.0
# The mode of the integer list is: 106
# The geometric mean of the list of integers is 108.26386432732649
# The harmonic mean of the list of values is 107.60014078452883
# The midrange of the given list is: 109.5
# The trimmed mean for the given data is: 108.8875

# %%
#2 . Generate a list of 500 integers containing values between 200 to 300 and store it in the variable `int_list2`. After generating the list, find the following.

# (i) Compare the given list of visualization for the given data:
 #1. Frequency & Gaussian distribution
 #2. Frequency smoothened KDE plot
 #3. Gaussian distribution & smoothened KDE plot

int_list2 = np.random.randint(200,300,500)



plt.hist(int_list2, bins=10, edgecolor='black')


plt.xlabel('Value Range')
plt.ylabel('Frequency')
plt.title('Frequency Distribution of int_list2')


plt.show()

from scipy.stats import norm


mean = np.mean(int_list2)
std_dev = np.std(int_list2)


plt.figure(figsize=(10, 6))
plt.hist(int_list2, bins=30, density=True, alpha=0.6, color='g', edgecolor='black')

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mean, std_dev)
plt.plot(x, p, 'k', linewidth=2)


plt.title('Gaussian Distribution')
plt.xlabel('Value')
plt.ylabel('Density')

plt.show()

# %%
#2
plt.figure(figsize=(10, 8))
sns.kdeplot(int_list2)


plt.title('Kernel Density Estimate Plot of int_list2')
plt.xlabel('Value')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
#3

#(ii) Write a Python function to calculate the range of a given list of numbers

print("The range of the given list is",(max(int_list2)-min(int_list2)))

#(iii) Create a program to find the variance and standard deviation of a list of numbers.

print("The variance of the list of integers is ",np.var(int_list))
print("The standard deviation of the list of integers is:",np.std(int_list))

# (iv) Implement a function to compute the interquartile range (IQR) of a list of values
print("The IQR of the dataset is:",np.percentile(int_list2,75)-np.percentile(int_list2,25))

#(v)  Build a program to calculate the coefficient of variation for a dataset
print("The coefficient of variation of the dataset:",((np.std(int_list2)/np.mean(int_list2))*100))

#(vi) Write a Python function to find the mean absolute deviation (MAD) of a list of numbers.

mean = np.mean(int_list2)

print("The mean absolute value of the dataset:",np.mean(np.abs(int_list2-mean)))

#(vii) Write a program to calculate the quartile deviation of a list of values:

print("The quartile deviation of the given dataset is:",(np.percentile(int_list2,75)-np.percentile(int_list2,25))/2)

# (viii) Implement a function to find the range-based coefficient of dispersion for a dataset

print("The coefficient of dispersion:",((max(int_list2)-min(int_list2))/mean)*100)
# Out:
# The range of the given list is 99
# The variance of the list of integers is  144.9851
# The standard deviation of the list of integers is: 12.040975874072666
# The IQR of the dataset is: 50.0
# The coefficient of variation of the dataset: 11.535070635277627
# The mean absolute value of the dataset: 24.8132
# The quartile deviation of the given dataset is: 25.0
# The coefficient of dispersion: 39.88397389412618

# %%
#3  Write a Python class representing a discrete random variable with methods to calculate its expected value and variance.

class DiscreteRandomVariable:
    def __init__(self, values, probabilities):

        if len(values) != len(probabilities):
            raise ValueError("The number of values and probabilities must be the same.")
        if not np.isclose(sum(probabilities), 1):
            raise ValueError("Probabilities must sum to 1.")

        self.values = np.array(values)
        self.probabilities = np.array(probabilities)

    def expected_value(self):

        return np.sum(self.values * self.probabilities)

    def variance(self):

        mean = self.expected_value()
        return np.sum((self.values - mean)**2 * self.probabilities)


values = [1, 2, 3, 4]
probabilities = [0.1, 0.2, 0.3, 0.4]

random_variable = DiscreteRandomVariable(values, probabilities)
print("Expected Value:", random_variable.expected_value())
print("Variance:", random_variable.variance())
# Out:
# Expected Value: 3.0
# Variance: 1.0

# %%
#4  Implement a program to simulate the rolling of a fair six-sided die and calculate the expected value and variance of the outcomes


num_rolls = 10000  # Number of die rolls


rolls = np.random.randint(1, 7, size=num_rolls)


expected_value = np.mean(rolls)


variance = np.var(rolls)

print(f"Expected Value: {expected_value:.2f}")
print(f"Variance: {variance:.2f}")
# Out:
# Expected Value: 3.50
# Variance: 2.92

# %%
#5 Create a Python Program to generate random samples from a given Probability distribution and calculate the mean and variance

#Let the probability distribution be the poisson distribution

samples = np.random.poisson(lam=5,size=1000)

sample_mean = np.mean(samples)
sample_variance = np.var(samples)

print("Mean of the sample is:",sample_mean)
print("Variance of the sample is:",sample_variance)
# Out:
# Mean of the sample is: 4.964
# Variance of the sample is: 4.998704000000001

# %%
#6 Write a Python script to generate random numbers from a Gaussian (normal) distribution and compute the mean, variance, and standard deviation of the samples.




mean = 0
std_dev = 1
sample_size = 1000


samples = np.random.normal(loc=mean, scale=std_dev, size=sample_size)


computed_mean = np.mean(samples)
computed_variance = np.var(samples)
computed_std_dev = np.std(samples)


print(f"Generated Samples (first 10): {samples[:10]}")
print(f"Mean of samples: {computed_mean:.4f}")
print(f"Variance of samples: {computed_variance:.4f}")
print(f"Standard deviation of samples: {computed_std_dev:.4f}")
# Out:
# Generated Samples (first 10): [-1.53440612e+00  1.16948180e+00 -2.17670009e-01 -1.08785528e+00
#  -1.05014308e+00 -7.48195064e-01  6.41319386e-01  2.26570949e+00
#  -8.89252746e-01 -1.64140358e-03]
# Mean of samples: 0.0323
# Variance of samples: 1.0017
# Standard deviation of samples: 1.0008

# %%
#7  Use seaborn library to load `tips` dataset. Find the following from the dataset for the columns `total_bill` and `tip`:

#(i) Write a Python function that calculates their skewness.

df=sns.load_dataset('tips')

df[['total_bill','tip']]

from scipy.stats import skew

skewness_bill = skew(df['total_bill'])

print(skewness_bill)

skewness_tips= skew(df['tip'])

print(skewness_tips)



#(ii)Create a program that determines whether the columns exhibit positive skewness, negative skewness, or is approximately symmetric

for column in df.columns:
  if df[column].dtype!='category':
    if skew(df[column])>0:
      print(column,"is Positively skewed")
    elif skew(df[column])<0:
      print(column,"is negatively skewed")
    elif rint(skew(df[column]))==0:
      print(column,"is approximately symmetric")

#(iii) Write a function that calculates the covariance between two columns.

def calculate_cov(col1,col2):
  return df[col1].cov(df[col2])

calculate_cov('tip','size')

# (iv) Implement a Python program that calculates the Pearson correlation coefficient between two columns.

from scipy.stats import pearsonr

pearson_corr = pearsonr(df['tip'], df['size'])

print("The pearson coefficient b/w tip and size is:",pearson_corr[0])

#(v) Write a script to visualize the correlation between two specific columns in a Pandas DataFrame using scatter plots.
# Out:
# 1.1262346334818638
# 1.4564266884221506
# total_bill is Positively skewed
# tip is Positively skewed
# size is Positively skewed
# The pearson coefficient b/w tip and size is: 0.4892987752303571

# %%
#8 Write a Python function to calculate the probability density function (PDF) of a continuous random variable for a given normal distribution.

def normal_pdf(x, mean, std_dev):

    coefficient = 1 / (np.sqrt(2 * np.pi) * std_dev)
    exponent = -((x - mean) ** 2) / (2 * std_dev ** 2)
    return coefficient * np.exp(exponent)


x = 0.5
mean = 0.0
std_dev = 1.0

pdf_value = normal_pdf(x, mean, std_dev)
print(f"PDF at x={x}: {pdf_value}")
# Out:
# PDF at x=0.5: 0.3520653267642995

# %%
#9  Create a program to calculate the cumulative distribution function (CDF) of exponential distribution.



def exp_cdf(x, rate):

    if x < 0:
        return 0.0
    return 1 - np.exp(-rate * x)


x = 1.5
rate = 0.5

cdf_value = exp_cdf(x, rate)
print(f"CDF at x={x}: {cdf_value}")
# Out:
# CDF at x=1.5: 0.5276334472589853

# %%
#10 Write a Python function to calculate the probability mass function (PMF) of Poisson distribution.




def poisson_pmf(k, lam):

    if k < 0 or not isinstance(k, int):
        raise ValueError("k must be a non-negative integer.")


    return (lam ** k * np.exp(-lam)) / math.factorial(k)


k = 3
lam = 2.5

pmf_value = poisson_pmf(k, lam)
print(f"PMF at k={k}: {pmf_value}")
# Out:
# PMF at k=3: 0.21376301724973645

# %%
#11 A company wants to test if a new website layout leads to a higher conversion rate (percentage of visitors who make a purchase). They collect data from the old and new layouts to compare.

# 50 purchases out of 1000 visitors
old_layout = np.array([1] * 50 + [0] * 950)
 # 70 purchases out of 1000 visitors
new_layout = np.array([1] * 70 + [0] * 930)


from statsmodels.stats.proportion import proportions_ztest


purchases_old = np.sum(old_layout)
purchases_new = np.sum(new_layout)

# visitors
total_old = len(old_layout)
total_new = len(new_layout)


count = np.array([purchases_old, purchases_new])
nobs = np.array([total_old, total_new])

z_stat, p_value = proportions_ztest(count, nobs)

print(f"Z-Statistic: {z_stat}")
print(f"P-Value: {p_value}")


if p_value < 0.05:
    print("There is a significant difference in purchase rates between the old and new layouts.")
else:
    print("There is no significant difference in purchase rates between the old and new layouts.")
# Out:
# Z-Statistic: -1.883108942886774
# P-Value: 0.059685605532426224
# There is no significant difference in purchase rates between the old and new layouts.
# 50

# %%
#12  A tutoring service claims that its program improves students' exam scores. A sample of students who participated in the program was taken, and their scores before and after the program were recorded.


from scipy.stats import norm


before_program = np.array([75, 80, 85, 70, 90, 78, 92, 88, 82, 87])
after_program = np.array([80, 85, 90, 80, 92, 80, 95, 90, 85, 88])


mean_before = np.mean(before_program)
mean_after = np.mean(after_program)
std_before = np.std(before_program, ddof=1)
std_after = np.std(after_program, ddof=1)


n_before = len(before_program)
n_after = len(after_program)


pooled_std = np.sqrt((std_before**2 / n_before) + (std_after**2 / n_after))


z_stat = (mean_before - mean_after) / pooled_std


p_value = 2 * norm.sf(np.abs(z_stat))

print(f"Z-Statistic: {z_stat:.4f}")
print(f"P-Value: {p_value:.4f}")

# Interpretation
if p_value < 0.05:
    print("There is a significant difference in test scores before and after the program.")
else:
    print("There is no significant difference in test scores before and after the program.")
# Out:
# Z-Statistic: -1.3600
# P-Value: 0.1738
# There is no significant difference in test scores before and after the program.

# %%
#13  A pharmaceutical company wants to determine if a new drug is effective in reducing blood pressure. They conduct a study and record blood pressure measurements before and after administering the drug

before_drug = np.array([145, 150, 140, 135, 155, 160, 152, 148, 130, 138])
after_drug = np.array([130, 140, 132, 128, 145, 148, 138, 136, 125, 130])




mean_before = np.mean(before_drug)
mean_after = np.mean(after_drug)
std_before = np.std(before_drug, ddof=1)
std_after = np.std(after_drug, ddof=1)


n_before = len(before_drug)
n_after = len(after_drug)


pooled_std = np.sqrt((std_before**2 / n_before) + (std_after**2 / n_after))


z_stat = (mean_before - mean_after) / pooled_std

p_value = norm.sf(z_stat)

print(f"Z-Statistic: {z_stat:.4f}")
print(f"P-Value: {p_value:.4f}")


if p_value < 0.05:
    print("There is a significant decrease in blood pressure after taking the drug.")
else:
    print("There is no significant decrease in blood pressure after taking the drug.")
# Out:
# Z-Statistic: 2.6396
# P-Value: 0.0042
# There is a significant decrease in blood pressure after taking the drug.

# %%
#14 A customer service department claims that their average response time is less than 5 minutes. A sample of recent customer interactions was taken, and the response times were recorded.

response_times = np.array([4.3, 3.8, 5.1, 4.9, 4.7, 4.2, 5.2, 4.5, 4.6, 4.4])




hypothesized_mean = 5.0


sample_mean = np.mean(response_times)
sample_std = np.std(response_times, ddof=1)


n = len(response_times)

z_stat = (sample_mean - hypothesized_mean) / (sample_std / np.sqrt(n))


p_value = norm.sf(z_stat)

print(f"Z-Statistic: {z_stat:.4f}")
print(f"P-Value: {p_value:.4f}")


if p_value < 0.05:
    print("There is a significant difference indicating that the average response time is greater than 5 minutes.")
else:
    print("There is no significant difference indicating that the average response time is greater than 5 minutes.")

#Therefore, the claims are true
# Out:
# Z-Statistic: -3.1845
# P-Value: 0.9993
# There is no significant difference indicating that the average response time is greater than 5 minutes.

# %%
#15  A company is testing two different website layouts to see which one leads to higher click-through rates. Write a Python function to perform an A/B test analysis, including calculating the t-statistic, degrees of freedom, and p-value

layout_a_clicks = np.array([28, 32, 33, 29, 31, 34, 30, 35, 36, 37])
layout_b_clicks = np.array([40, 41, 38, 42, 39, 44, 43, 41, 45, 47])

mean_a = np.mean(layout_a_clicks)
mean_b = np.mean(layout_b_clicks)
std_a = np.std(layout_a_clicks, ddof=1)
std_b = np.std(layout_b_clicks, ddof=1)


n_a = len(layout_a_clicks)
n_b = len(layout_b_clicks)


t_stat, p_value = stats.ttest_ind(layout_a_clicks, layout_b_clicks, equal_var=False)


df = (std_a**2 / n_a + std_b**2 / n_b) ** 2 / (
    ((std_a**2 / n_a) ** 2 / (n_a - 1)) + ((std_b**2 / n_b) ** 2 / (n_b - 1))
)

print(f"T-Statistic: {t_stat:.4f}")
print(f"Degrees of Freedom: {df:.4f}")
print(f"P-Value: {p_value:.4f}")

if p_value < 0.05:
    print("There is a significant difference in click rates between layout A and layout B.")
else:
    print("There is no significant difference in click rates between layout A and layout B.")
# Out:
# T-Statistic: -7.2981
# Degrees of Freedom: 17.8799
# P-Value: 0.0000
# There is a significant difference in click rates between layout A and layout B.

# %%
#16 .A pharmaceutical company wants to determine if a new drug is more effective than an existing drug in reducing cholesterol levels. Create a program to analyze the clinical trial data and calculate the statistic and p-value for the treatment effect.

existing_drug_levels = np.array([180, 182, 175, 185, 178, 176, 172, 184, 179, 183])
new_drug_levels = np.array([170, 172, 165, 168, 175, 173, 170, 178, 172, 176])


mean_existing = np.mean(existing_drug_levels)
mean_new = np.mean(new_drug_levels)
std_existing = np.std(existing_drug_levels, ddof=1)
std_new = np.std(new_drug_levels, ddof=1)




t_stat, p_value = stats.ttest_ind(existing_drug_levels, new_drug_levels, equal_var=False)



print(f"T-Statistic: {t_stat:.4f}")

print(f"P-Value: {p_value:.4f}")


if p_value < 0.05:
    print("The new drug is significantly more effective in reducing cholesterol compared to the existing drug.")
else:
    print("There is no significant difference in cholesterol reduction between the new drug and the existing drug.")
# Out:
# T-Statistic: 4.1405
# P-Value: 0.0006
# The new drug is significantly more effective in reducing cholesterol compared to the existing drug.

# %%
 #17 A school district introduces an educational intervention program to improve math scores. Write a Python function to analyze pre- and post-intervention test scores, calculating the t-statistic and p-value to determine if the intervention had a significant impact.


pre_intervention_scores = np.array([80, 85, 90, 75, 88, 82, 92, 78, 85, 87])
post_intervention_scores = np.array([90, 92, 88, 92, 95, 91, 96, 93, 89, 93])

differences = post_intervention_scores - pre_intervention_scores


mean_diff = np.mean(differences)
std_diff = np.std(differences, ddof=1)
n = len(differences)


t_stat = mean_diff / (std_diff / np.sqrt(n))


p_value = 2 * stats.t.sf(np.abs(t_stat), df=n-1)

print(f"T-Statistic: {t_stat:.4f}")
print(f"P-Value: {p_value:.4f}")


if p_value < 0.05:
    print("The intervention program has significantly improved scores.")
else:
    print("There is no significant improvement in scores.")
# Out:
# T-Statistic: 4.4284
# P-Value: 0.0017
# The intervention program has significantly improved scores.

# %%
#18 An HR department wants to investigate if there's a gender-based salary gap within the company. Develop
#a program to analyze salary data, calculate the t-statistic, and determine if there's a statistically
# significant difference between the average salaries of male and female employees.


np.random.seed(0)
male_salaries = np.random.normal(loc=50000, scale=10000, size=20)
female_salaries = np.random.normal(loc=55000, scale=9000, size=20)

mean_male = np.mean(male_salaries)
mean_female = np.mean(female_salaries)
std_male = np.std(male_salaries, ddof=1)
std_female = np.std(female_salaries, ddof=1)



t_stat, p_value = stats.ttest_ind(male_salaries, female_salaries, equal_var=False)



print(f"T-Statistic: {t_stat:.4f}")

print(f"P-Value: {p_value:.4f}")

if p_value < 0.05:
    print("There is a significant difference in average salaries between male and female employees.")
else:
    print("There is no significant difference in average salaries between male and female employees.")
# Out:
# T-Statistic: 0.0611
# P-Value: 0.9516
# There is no significant difference in average salaries between male and female employees.

# %%
#19 A manufacturer produces two different versions of a product and wants to compare their quality scores. Create a Python function to analyze quality assessment data, calculate the t-statistic, and decide whether there's a significant difference in quality between the two versions


version1_scores = np.array([85, 88, 82, 89, 87, 84, 90, 88, 85, 86, 91, 83, 87, 84, 89, 86, 84, 88, 85, 86, 89, 90, 87, 88, 85])
version2_scores = np.array([80, 78, 83, 81, 79, 82, 76, 80, 78, 81, 77, 82, 80, 79, 82, 79, 80, 81, 79, 82, 79, 78, 80, 81, 82])

mean_version1 = np.mean(version1_scores)
mean_version2 = np.mean(version2_scores)
std_version1 = np.std(version1_scores, ddof=1)
std_version2 = np.std(version2_scores, ddof=1)


t_stat, p_value = stats.ttest_ind(version1_scores, version2_scores, equal_var=False)



print(f"T-Statistic: {t_stat:.4f}")

print(f"P-Value: {p_value:.4f}")


if p_value < 0.05:
    print("There is a significant difference in the quality scores between the two versions.")
else:
    print("There is no significant difference in the quality scores between the two versions.")
# Out:
# T-Statistic: 11.3258
# P-Value: 0.0000
# There is a significant difference in the quality scores between the two versions.

# %%
#20 A restaurant chain collects customer satisfaction scores for two different branches. Write a program to analyze the scores, calculate the t-statistic, and determine if there's a statistically significant difference in customer satisfaction between the branches


branch_a_scores = np.array([4, 5, 3, 4, 5, 4, 5, 3, 4, 4, 5, 4, 4, 3, 4, 5, 5, 4, 3, 4, 5, 4, 3, 5, 4, 4, 5, 3, 4, 5, 4])
branch_b_scores = np.array([3, 4, 2, 3, 4, 3, 4, 2, 3, 3, 4, 3, 3, 2, 3, 4, 4, 3, 2, 3, 4, 3, 2, 4, 3, 3, 4, 2, 3, 4, 3])



t_stat, p_value = stats.ttest_ind(branch_a_scores, branch_b_scores, equal_var=False)



print(f"T-Statistic: {t_stat:.4f}")

print(f"P-Value: {p_value:.4f}")

if p_value < 0.05:
    print("There is a significant difference in customer satisfaction between the two branches.")
else:
    print("There is no significant difference in customer satisfaction between the two branches.")
# Out:
# T-Statistic: 5.4801
# P-Value: 0.0000
# There is a significant difference in customer satisfaction between the two branches.

# %%
#21  A political analyst wants to determine if there is a significant association between age groups and voter preferences (Candidate A or Candidate B).
#They collect data from a sample of 500 voters and classify them into different age groups and candidate preferences.
#Perform a Chi-Square test to determine if there is a significant association between age groups and voter preferences.

from scipy.stats import chi2_contingency


np.random.seed(0)
age_groups = np.random.choice(['18-30', '31-50', '51+', '51+'], size=30)
voter_preferences = np.random.choice(['Candidate A', 'Candidate B'], size=30)







data = pd.DataFrame({'Age Group': age_groups, 'Voter Preference': voter_preferences})

contingency_table = pd.crosstab(data['Age Group'], data['Voter Preference'])


chi2_stat, p_value, dof, expected = chi2_contingency(contingency_table)

print("Contingency Table:")
print(contingency_table)
print("\nChi-Square Statistic:", chi2_stat)
print("Degrees of Freedom:", dof)
print("P-Value:", p_value)

if p_value < 0.05:
    print("There is a significant association between age groups and voter preferences.")
else:
    print("There is no significant association between age groups and voter preferences.")
# Out:
# Contingency Table:
# Voter Preference  Candidate A  Candidate B
# Age Group
# 18-30                       2            6
# 31-50                       4            4
# 51+                         5            9
#
# Chi-Square Statistic: 1.086807928913192
# Degrees of Freedom: 2
# P-Value: 0.5807679703526951
# There is no significant association between age groups and voter preferences.

# %%
#22. A company conducted a customer satisfaction survey to determine if there is a significant relationship
# between product satisfaction levels (Satisfied, Neutral, Dissatisfied) and the region where customers are
# located (East, West, North, South). The survey data is summarized in a contingency table. Conduct a Chi
# Square test to determine if there is a significant relationship between product satisfaction levels and
# customer regions




data = np.array([[50, 30, 40, 20],
                 [30, 40, 30, 50],
                 [20, 30, 40, 30]])


chi2_stat, p_value, dof, expected = chi2_contingency(data)

print("Contingency Table:")
print(data)
print("\nChi-Square Statistic:", chi2_stat)
print("Degrees of Freedom:", dof)
print("P-Value:", p_value)
print("Expected Frequencies:")
print(expected)


if p_value < 0.05:
    print("There is a significant relationship between product satisfaction levels and customer regions.")
else:
    print("There is no significant relationship between product satisfaction levels and customer regions.")
# Out:
# Contingency Table:
# [[50 30 40 20]
#  [30 40 30 50]
#  [20 30 40 30]]
#
# Chi-Square Statistic: 27.777056277056275
# Degrees of Freedom: 6
# P-Value: 0.00010349448486004387
# Expected Frequencies:
# [[34.14634146 34.14634146 37.56097561 34.14634146]
#  [36.58536585 36.58536585 40.24390244 36.58536585]
#  [29.26829268 29.26829268 32.19512195 29.26829268]]
# There is a significant relationship between product satisfaction levels and customer regions.

# %%
#23 . A company implemented an employee training program to improve job performance (Effective, Neutral,
#Ineffective). After the training, they collected data from a sample of employees and classified them based
#on their job performance before and after the training. Perform a Chi-Square test to determine if there is a
#significant difference between job performance levels before and after the training.


data = np.array([[50, 30, 20], [30, 40, 30], [20, 30, 40]])

 # Sample data: Job performance levels before (rows) and after (columns) training




data = np.array([[50, 30, 20],
                 [30, 40, 30],
                 [20, 30, 40]])


chi2_stat, p_value, dof, expected = chi2_contingency(data)

print("Chi-Square Statistic:", chi2_stat)
print("p-value:", p_value)
print("Degrees of Freedom:", dof)
print("Expected Frequencies Table:")
print(expected)


alpha = 0.05
if p_value < alpha:
    print("There is a significant difference in job performance levels before and after training.")
else:
    print("There is no significant difference in job performance levels before and after training.")
# Out:
# Chi-Square Statistic: 22.161728395061726
# p-value: 0.00018609719479882557
# Degrees of Freedom: 4
# Expected Frequencies Table:
# [[34.48275862 34.48275862 31.03448276]
#  [34.48275862 34.48275862 31.03448276]
#  [31.03448276 31.03448276 27.93103448]]
# There is a significant difference in job performance levels before and after training.

# %%
#24 A company produces three different versions of a product: Standard, Premium, and Deluxe. The
#company wants to determine if there is a significant difference in customer satisfaction scores among the
#three product versions. They conducted a survey and collected customer satisfaction scores for each
#version from a random sample of customers. Perform an ANOVA test to determine if there is a significant
#difference in customer satisfaction scores


from scipy.stats import f_oneway


standard_scores = [80, 85, 90, 78, 88, 82, 92, 78, 85, 87]
premium_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]
deluxe_scores = [95, 98, 92, 97, 96, 94, 98, 97, 92, 99]


f_stat, p_value = f_oneway(standard_scores, premium_scores, deluxe_scores)

print("ANOVA Test:")
print("F-Statistic:", f_stat)
print("P-Value:", p_value)


if p_value < 0.05:
    print("There is a significant difference in customer satisfaction scores among the product versions.")
else:
    print("There is no significant difference in customer satisfaction scores among the product versions.")
# Out:
# ANOVA Test:
# F-Statistic: 27.03556231003039
# P-Value: 3.5786328857349003e-07
# There is a significant difference in customer satisfaction scores among the product versions.
